# %%
import requests
import json
# Extract information
response = requests.post('http://127.0.0.1:8000/extract', json={
    "message": """광고 제목:[SK텔레콤] 2월 0 day 혜택 안내
광고 내용:(광고)[SKT] 2월 0 day 혜택 안내__[2월 10일(토) 혜택]_만 13~34세 고객이라면_베어유 모든 강의 14일 무료 수강 쿠폰 드립니다!_(선착순 3만 명 증정)_▶ 자세히 보기: http://t-mms.kr/t.do?m=#61&s=24589&a=&u=https://bit.ly/3SfBjjc__■ 에이닷 X T 멤버십 시크릿코드 이벤트_에이닷 T 멤버십 쿠폰함에 ‘에이닷이빵쏜닷’을 입력해보세요!_뚜레쥬르 데일리우유식빵 무료 쿠폰을 드립니다._▶ 시크릿코드 입력하러 가기: https://bit.ly/3HCUhLM__■ 문의: SKT 고객센터(1558, 무료)_무료 수신거부 1504""",
    "llm_model": "ax",
    "product_info_extraction_mode": "llm",
    "entity_matching_mode": "llm",
    "extract_entity_dag": True
})

result = response.json()
print(json.dumps(result['result'], indent=4, ensure_ascii=False))
# Out:
# {
#     "channel": [
#         {
#             "action": "추가 정보",
#             "store_info": [],
#             "type": "URL",
#             "value": "http://t-mms.kr/t.do?m=#61&s=24589&a=&u=https://bit.ly/3SfBjjc"
#         },
#         {
#             "action": "참여",
#             "store_info": [],
#             "type": "URL",
#             "value": "https://bit.ly/3HCUhLM"
#         },
#         {
#             "action": "문의",
#             "store_info": [],
#             "type": "전화번호",
#             "value": "1558"
#         },
#         {
#             "action": "수신 거부",
#             "store_info": [],
#             "type": "전화번호",
#             "value": "1504"
#         }
#     ],
#     "entity_dag": [
#         "(시크릿코드:입력) -[입력하면]-> (식빵쿠폰:수령)",
#         "(앱:접속) -[접속하면]-> (시크릿코드:입력)",
#         "(웹사이트:접속) -[접속하면]-> (베어유쿠폰:수령)"
#     ],
#     "pgm": [
#         {
#             "pgm_id": "2019CCEPM01",
#             "pgm_nm": "[마케팅_Care]사용법/혜택/이벤트안내_T멤버십"
#         },
#         {
#             "pgm_id": "2019CCEPM03",
#             "pgm_nm": "[마케팅_Care]사용법/혜택/이벤트안내_SKT"
#         }
#     ],
#     "product": [
#         {
#             "expected_action": "기타",
#             "item_in_voca": [
#                 {
#                     "item_id": [
#                         "5321_4603",
#                         "5321_4360",
#                         "5321_4846",
#                         "5321_3860",
#                         "5321_5526",
#                         "5321_3174",
#                         "5321_5248",
#                         "5321_3626",
#                         "5321_5414",
#                         "5321_5051",
#                         "5321_3337",
#                         "5321_8166",
#                         "5321_7554",
#                         "5321_9200",
#                         "5321_9823",
#                         "5321_7293",
#                         "5321_9464",
#                         "5321_7897",
#                         "5321_6816",
#                         "5321_8909",
#                         "5321_4111",
#                         "5321_5736",
#                         "5321_8691",
#                         "5321_6589",
#                         "5321_8426",
#                         "5321_6099",
#                         "5321_6412"
#                     ],
#                     "item_nm": "GS25_0 day 10일 혜택"
#                 },
#                 {
#                     "item_id": [
#                         "5321_4428",
#                         "5321_5031",
#                         "5321_4645",
#                         "5321_3234",
#                         "5321_3693",
#                         "5321_4944",
#                         "5321_5119",
#                         "5321_4156",
#                         "5321_3901",
#                         "5321_5538",
#                         "5321_7318",
#                         "5321_9893",
#                         "5321_9582",
#                         "5321_9253",
#                         "5321_7919",
#                         "5321_8987",
#                         "5321_7052",
#                         "5321_8233",
#                         "5321_6443",
#                         "5321_8478",
#                         "5321_3442",
#                         "5321_6736",
#                         "5321_8730",
#                         "5321_6116",
#                         "5321_7625",
#                         "5321_5750",
#                         "5321_5387",
#                         "5321_4886"
#                     ],
#                     "item_nm": "GS25_0 day 20일 혜택"
#                 },
#                 {
#                     "item_id": [
#                         "5495_9469"
#                     ],
#                     "item_nm": "톤28_0 day 10일 혜택"
#                 },
#                 {
#                     "item_id": [
#                         "5495_9588"
#                     ],
#                     "item_nm": "톤28_0 day 20일 혜택"
#                 },
#                 {
#                     "item_id": [
#                         "5495_9601"
#                     ],
#                     "item_nm": "톤28_0 day 30일 혜택"
#                 }
#             ],
#             "item_name_in_msg": "2월 0 day 혜택"
#         }
#     ],
#     "purpose": [
#         "혜택 안내",
#         "쿠폰 제공 안내",
#         "이벤트 응모 유도"
#     ],
#     "title": "[SK텔레콤] 2월 0 day 혜택 안내"
# }
