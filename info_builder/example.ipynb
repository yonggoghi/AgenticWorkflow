# %%
import pandas as pd

# %%
pd.read_csv("output/test_with_details.csv").sort_values("detail_url",ascending=False).drop_duplicates()
# Out:
#            id                                               name  \
# 1  PR00000684                                  스피킹맥스 두근톡 30일 이용권
# 4  PR00000625                                SNOW VIP 1개월 구독권 할인
# 8  PR00000611                              오토카지 15,000원 할인 쿠폰 2장
# 3  PR00000605                                          월간과자 마니아팩
# 6  PR00000540                            횡성한우큐브 된장 끄리다(17g *18입)
# 0  PR00000538                                T 우주패스 with Disney+
# 7  PR00000247         롯데시네마 영화 3천 원 관람권 1장, 영화 할인권 4장, 콤보 할인권 2장
# 5  PR00000239         CJ더마켓 10,000원 적립금, 무료배송 쿠폰, 장바구니 40% 할인 쿠폰
# 2  PR00000104  Amazon 무료배송, 쿠폰 2개(총 10,000원), 쇼핑 포인트 3,000P, ...
#
#                                          description  \
# 1  스피킹맥스 30일 이용권으로, 구독 주기에 맞춰 혜택 쿠폰 자동 발급 및 스피킹맥스...
# 4                                       SNOW VIP 이용권
# 8                                           오토카지 쿠폰팩
# 3                                     월간과자 마니아팩 정기배송
# ...
