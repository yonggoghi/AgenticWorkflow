# %%
import pandas as pd

# %%
pd.read_csv("output/test_with_details.csv").sort_values("detail_url",ascending=False).drop_duplicates()
# Out:
#              id                        name  \
# 0    PR00000686      T 우주패스 올리브영&스타벅스&이마트24
# 6    PR00000540          횡성한우큐브 된장 끄리다 정기배송
# 127  PR00000540     횡성한우큐브 된장 끄리다(17g *18입)
# 1    PR00000684           스피킹맥스 두근톡 30일 이용권
# 2    PR00000104              T 우주패스 쇼핑 11번가
# ..          ...                         ...
# 182  PR00000606                   Wavve 이용권
# 183  PR00000617   T 우주패스 쇼핑 11번가 with 밀리의서재
# 184  PR00000627             Wavve 콘텐츠 팩 이용권
# 185  PR00000628                     FLO 이용권
# 186  PR00000675  T 우주패스 쇼핑 11번가 with 티빙 이용권
#
#                                            description  \
# 0    올리브영 3종 쿠폰, 스타벅스 20% 할인, 이마트24 1,000원당 200원 할인...
# 6      횡성한우큐브 된장 끄리다(17g *18입)를 매월 정기배송으로 제공하는 서비스입니다.
# 127                                      12% 할인, 무료 배송
# 1                                    스피킹맥스 두근톡 30일 이용권
# 2    Amazon 무료배송, 쿠폰 2개(총 10,000원), 쇼핑 포인트 3,000P, ...
# ..                                                 ...
# ...
