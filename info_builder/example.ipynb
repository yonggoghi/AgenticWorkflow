# %%
import pandas as pd

# %%
pd.read_csv("output/products_basic.csv").drop_duplicates()
# Out:
#              id                        name  \
# 0    PR00000686      T 우주패스 올리브영&스타벅스&이마트24
# 1    PR00000109               T 우주패스 편의점&카페
# 2    PR00000341             YouTube Premium
# 3    PR00000501                     Netflix
# 4    PR00000344                       CU 할인
# ..          ...                         ...
# 181  PR00000606                   Wavve 이용권
# 182  PR00000617   T 우주패스 쇼핑 11번가 with 밀리의서재
# 183  PR00000627             Wavve 콘텐츠 팩 이용권
# 184  PR00000628                     FLO 이용권
# 185  PR00000675  T 우주패스 쇼핑 11번가 with 티빙 이용권
#
#                                            description  detail_url
# 0     올리브영 3종 쿠폰팩, 스타벅스 20% 할인, 이마트24 1,000원 당 200원 할인         NaN
# 1               세븐일레븐/ 투썸플레이스 최대 30% 할인 + 추가 상품 1~2개 더         NaN
# 2                  YouTube 광고 없이 감상, 오프라인 저장, 백그라운드 재생         NaN
# 3                                          Netflix 이용권         NaN
# 4                             CU 매장 구매 1,000원당 300원 할인         NaN
# ...
